# %% [markdown]
# ## Score Family Grand Prix Predictions

# %%
from f1_scoring_tools import score_gp

filename = '11hungary2026.csv'
sprint = False # If sprint weekend, True. If non-sprint weekend, False. 
df = score_gp(filename, sprint)
df
# Out:
#          Dad    Mom  Quincey  Wynn  Paige   Rees
# FP1      6.0    2.0      1.0   0.0    5.0    2.0
# FP2      1.0    3.0      6.0   0.0    5.0    1.0
# FP3      6.0    2.0      6.0   0.0    4.0    2.0
# Quali   12.0   15.0     15.0   0.0   19.0   15.0
# Race   175.0  125.0    175.0   0.0  165.0  130.0

# %%
# Need to account for multiple entries of the same driver in one session (See paige Belgium FP3)
# Write error flags
